# %% [markdown]
# <a href="https://colab.research.google.com/github/useanynoms-commits/IDRA/blob/main/Assignment_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Load the CSV dataset
df = pd.read_csv('Day7_Student_Dataset.csv')
print("="*60)
print("DATASET SUMMARY REPORT")
print("="*60)

# Dataset shape
print(f"\nDataset Shape: {df.shape[0]} rows and {df.shape[1]} columns")

# Column names
print(f"\nColumns: {list(df.columns)}")

# First few rows
print("\nFirst 5 rows:")
print(df.head())

# Last few rows
print("\nLast 5 rows:")
print(df.tail())

# Random samples
print("\nRandom 5 samples:")
print(df.sample(5))
# Out:
# ...
# DATASET SUMMARY REPORT
# ...
#
# Dataset Shape: 25 rows and 7 columns
#
# Columns: ['Student_ID', 'Name', 'Age', 'Course', 'Marks', 'Attendance_Percentage', 'City']
#
# First 5 rows:
#    Student_ID          Name  Age            Course  Marks  \
# 0        1001  Aarav Sharma   19      Data Science   87.0
# 1        1002     Zoya Khan   20                AI   92.0
# 2        1003   Rohan Mehta   18  Computer Science   76.0
# 3        1004  Ananya Singh   21      Data Science   81.0
# 4        1005     Kabir Ali   19                AI   69.0
#
#    Attendance_Percentage      City
# 0                   91.0  Srinagar
# 1                   95.0     Delhi
# 2                   82.0    Mumbai
# 3                   88.0  Srinagar
# 4                   76.0   Lucknow
#
# Last 5 rows:
#     Student_ID          Name  Age            Course  Marks  \
# 20        1021    Aman Kumar   18  Computer Science   74.0
# 21        1022    Alina Shah   19      Data Science   96.0
# ...
